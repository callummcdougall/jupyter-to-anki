# %%
from jupyter_to_anki import *

# %%
read_cards(filename="jupyter_to_anki_template", write=True)
# Out:
# Creating cards:
#
# 	2 cards with tag 'main_tag::sub_tag second_main_tag::second_sub_tag'
#
# Saving cards:
#
# 	1 card  with filename 'front-back.txt'
# 	1 card  with filename 'front.txt'
#
# ======== ERROR MESSAGES ========
#
# We found a single '**'-character in one one of the lines of your card. This will be interpreted as bold by the Python code, and they should come in even numbers. If you don't fix this error then it might mess up your card.

# %% [markdown]
# TAGS = main_tag::sub_tag second_main_tag::second_sub_tag

# %% [markdown]
# This is the front of **a two-sided card.
#
# This is some text which will be turned into a spoiler: (S)spoiler text(S).
#
# -
#
# This is the back of the card.
#
# (Q)
# This is a quote.
# Each time you study a card, the quote changes colour randomly.
# The colour is always light, so that you can read the text clearly.
# (Q)
# This is the source of the quote.
# The source can also go onto more than one line (e.g. if you want to give the book and the author).
# (Q)
#
# (Q)
# Here is a quote without a source.
# (Q)
#
# -h
#
# This is a hint.

# %% [markdown]
# This is a one-sided card.
#
# This is some text which will be turned into a spoiler: (S)spoiler text(S).
#
# Here is a block of code:
#
#     def add(a, b):
#         return a + b
#
#     >>> add(50, 50)
#     {{{100}}}
#
# Here is some inline markdown: **bold**, *italic* and `code font`.
#
# Here is an image:
#
# ![image.png](attachment:image.png)
#
# Here are some bullet points:
#
# * First point
# * Second point
#
# Here is a numbered list:
#
# 1. First point
# 2. Second point
#
# -h
#
# This is a hint.
